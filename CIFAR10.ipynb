# %% [markdown]
# # CIFAR-10 Classification with an LDA Head
# This notebook trains a lightweight convolutional encoder with an LDA head on CIFAR-10, alongside a softmax baseline, then visualises the learned embedding spaces side by side.

# %% [markdown]
# ### Setup

# %%
import torch, torch.nn as nn, torch.nn.functional as F
from torch.utils.data import DataLoader
from torchvision import datasets, transforms
from lda import SimplexLDAHead, DNLLLoss

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print('device =', device)
# Out:
# device = cuda

# %% [markdown]
# ### Data

# %%
mean = (0.4914, 0.4822, 0.4465)
std = (0.2470, 0.2435, 0.2616)
pin_memory = torch.cuda.is_available()

train_tfm = transforms.Compose([
    transforms.RandomCrop(32, padding=4),
    transforms.RandomHorizontalFlip(),
    transforms.ToTensor(),
    transforms.Normalize(mean, std),
])

test_tfm = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize(mean, std),
])

train_ds = datasets.CIFAR10(root='./data', train=True, transform=train_tfm, download=True)
test_ds  = datasets.CIFAR10(root='./data', train=False, transform=test_tfm, download=True)
train_ld = DataLoader(train_ds, batch_size=256, shuffle=True, num_workers=4, pin_memory=pin_memory)
test_ld  = DataLoader(test_ds,  batch_size=1024, shuffle=False, num_workers=4, pin_memory=pin_memory)
len(train_ds), len(test_ds)
# Out:
# (50000, 10000)

# %% [markdown]
# ### Model: encoder + heads (LDA + softmax)

# %%
class Encoder(nn.Module):
    def __init__(self, dim):
        super().__init__()
        self.features = nn.Sequential(
            nn.Conv2d(3, 64, 3, padding=1), nn.BatchNorm2d(64), nn.ReLU(inplace=True),
            nn.Conv2d(64, 64, 3, padding=1), nn.BatchNorm2d(64), nn.ReLU(inplace=True),
            nn.MaxPool2d(2),
            nn.Conv2d(64, 128, 3, padding=1), nn.BatchNorm2d(128), nn.ReLU(inplace=True),
            nn.Conv2d(128, 128, 3, padding=1), nn.BatchNorm2d(128), nn.ReLU(inplace=True),
            nn.MaxPool2d(2),
            nn.Conv2d(128, 256, 3, padding=1), nn.BatchNorm2d(256), nn.ReLU(inplace=True),
            nn.Conv2d(256, 256, 3, padding=1), nn.BatchNorm2d(256), nn.ReLU(inplace=True),
            nn.AdaptiveAvgPool2d(1),
        )
        self.proj = nn.Linear(256, dim)

    def forward(self, x):
        x = self.features(x)
        x = torch.flatten(x, 1)
        return self.proj(x)

class DeepLDA(nn.Module):
    def __init__(self, C, D):
        super().__init__()
        self.encoder = Encoder(D)
        self.head = SimplexLDAHead(C, D)

    def forward(self, x):
        z = self.encoder(x)
        return self.head(z)

# %% [markdown]
# ### Train & Eval

# %%
@torch.no_grad()
def evaluate(model, loader):
    model.eval()
    ok = tot = 0
    for x, y in loader:
        x, y = x.to(device), y.to(device)
        logits = model(x)
        ok += (logits.argmax(1) == y).sum().item()
        tot += y.size(0)
    return ok / tot

lda_model = DeepLDA(C=10, D=9).to(device)
lda_opt = torch.optim.Adam(lda_model.parameters())
#lda_loss_fn = nn.NLLLoss()
lda_loss_fn = DNLLLoss()

lda_train_acc = []
lda_test_acc = []

for epoch in range(1, 101):
    lda_model.train()
    loss_sum = acc_sum = n_sum = 0
    for x, y in train_ld:
        x, y = x.to(device), y.to(device)
        logits = lda_model(x)
        loss = lda_loss_fn(logits, y)
        lda_opt.zero_grad(set_to_none=True)
        loss.backward()
        lda_opt.step()
        with torch.no_grad():
            pred = logits.argmax(1)
            acc_sum += (pred == y).sum().item()
            n_sum += y.size(0)
            loss_sum += loss.item() * y.size(0)
    tr_acc = acc_sum / n_sum
    te_acc = evaluate(lda_model, test_ld)
    lda_train_acc.append(tr_acc)
    lda_test_acc.append(te_acc)
    print(f"[LDA {epoch:02d}] train loss={loss_sum/n_sum:.4f} acc={tr_acc:.4f} | test acc={te_acc:.4f}")
# Out:
# [LDA 01] train loss=8.0713 acc=0.5113 | test acc=0.4778
# [LDA 02] train loss=6.6823 acc=0.6745 | test acc=0.5659
# [LDA 03] train loss=5.9408 acc=0.7488 | test acc=0.6841
# [LDA 04] train loss=5.4089 acc=0.7880 | test acc=0.7605
# [LDA 05] train loss=5.0177 acc=0.8123 | test acc=0.7889
# [LDA 06] train loss=4.7091 acc=0.8303 | test acc=0.7656
# [LDA 07] train loss=4.4476 acc=0.8451 | test acc=0.6798
# [LDA 08] train loss=4.2296 acc=0.8593 | test acc=0.8223
# [LDA 09] train loss=4.0379 acc=0.8706 | test acc=0.7563
# [LDA 10] train loss=3.8677 acc=0.8791 | test acc=0.8269
# [LDA 11] train loss=3.7112 acc=0.8872 | test acc=0.8470
# [LDA 12] train loss=3.5839 acc=0.8948 | test acc=0.8539
# [LDA 13] train loss=3.4404 acc=0.9031 | test acc=0.8551
# [LDA 14] train loss=3.3431 acc=0.9074 | test acc=0.8634
# [LDA 15] train loss=3.2538 acc=0.9120 | test acc=0.8449
# [LDA 16] train loss=3.1413 acc=0.9177 | test acc=0.8694
# [LDA 17] train loss=3.0541 acc=0.9228 | test acc=0.8507
# [LDA 18] train loss=2.9687 acc=0.9272 | test acc=0.8687
# [LDA 19] train loss=2.8901 acc=0.9315 | test acc=0.8758
# [LDA 20] train loss=2.8251 acc=0.9342 | test acc=0.8763
# [LDA 21] train loss=2.7255 acc=0.9386 | test acc=0.8811
# [LDA 22] train loss=2.6914 acc=0.9413 | test acc=0.8642
# [LDA 23] train loss=2.6326 acc=0.9436 | test acc=0.8839
# [LDA 24] train loss=2.5876 acc=0.9467 | test acc=0.8791
# [LDA 25] train loss=2.5172 acc=0.9509 | test acc=0.8915
# [LDA 26] train loss=2.4540 acc=0.9534 | test acc=0.8905
# [LDA 27] train loss=2.4092 acc=0.9556 | test acc=0.8861
# [LDA 28] train loss=2.3785 acc=0.9561 | test acc=0.8815
# [LDA 29] train loss=2.2952 acc=0.9599 | test acc=0.8994
# [LDA 30] train loss=2.2763 acc=0.9614 | test acc=0.8900
# [LDA 31] train loss=2.2103 acc=0.9640 | test acc=0.8975
# [LDA 32] train loss=2.1858 acc=0.9652 | test acc=0.8822
# [LDA 33] train loss=2.1414 acc=0.9678 | test acc=0.8978
# [LDA 34] train loss=2.1095 acc=0.9692 | test acc=0.8983
# [LDA 35] train loss=2.0748 acc=0.9705 | test acc=0.8973
# [LDA 36] train loss=2.0682 acc=0.9701 | test acc=0.9014
# [LDA 37] train loss=2.0203 acc=0.9730 | test acc=0.9012
# [LDA 38] train loss=1.9761 acc=0.9762 | test acc=0.8886
# [LDA 39] train loss=1.9431 acc=0.9764 | test acc=0.8956
# [LDA 40] train loss=1.9309 acc=0.9776 | test acc=0.9015
# [LDA 41] train loss=1.9076 acc=0.9781 | test acc=0.8866
# [LDA 42] train loss=1.8865 acc=0.9789 | test acc=0.9038
# [LDA 43] train loss=1.8351 acc=0.9809 | test acc=0.8980
# [LDA 44] train loss=1.8376 acc=0.9811 | test acc=0.8993
# [LDA 45] train loss=1.8386 acc=0.9810 | test acc=0.8987
# [LDA 46] train loss=1.7808 acc=0.9832 | test acc=0.9060
# [LDA 47] train loss=1.7845 acc=0.9838 | test acc=0.9048
# [LDA 48] train loss=1.7626 acc=0.9843 | test acc=0.8996
# [LDA 49] train loss=1.7155 acc=0.9858 | test acc=0.9032
# [LDA 50] train loss=1.7226 acc=0.9855 | test acc=0.8930
# [LDA 51] train loss=1.6958 acc=0.9871 | test acc=0.9033
# [LDA 52] train loss=1.6871 acc=0.9874 | test acc=0.9005
# [LDA 53] train loss=1.6613 acc=0.9883 | test acc=0.8963
# [LDA 54] train loss=1.6467 acc=0.9884 | test acc=0.8939
# [LDA 55] train loss=1.6484 acc=0.9880 | test acc=0.9059
# [LDA 56] train loss=1.6129 acc=0.9895 | test acc=0.9062
# [LDA 57] train loss=1.5952 acc=0.9901 | test acc=0.8991
# [LDA 58] train loss=1.5799 acc=0.9905 | test acc=0.9063
# [LDA 59] train loss=1.5829 acc=0.9907 | test acc=0.9050
# [LDA 60] train loss=1.5702 acc=0.9908 | test acc=0.9050
# [LDA 61] train loss=1.5474 acc=0.9916 | test acc=0.9024
# [LDA 62] train loss=1.5353 acc=0.9920 | test acc=0.9036
# [LDA 63] train loss=1.5411 acc=0.9916 | test acc=0.9073
# [LDA 64] train loss=1.5297 acc=0.9917 | test acc=0.9018
# [LDA 65] train loss=1.5240 acc=0.9919 | test acc=0.9068
# [LDA 66] train loss=1.5135 acc=0.9919 | test acc=0.8964
# [LDA 67] train loss=1.4883 acc=0.9932 | test acc=0.9060
# [LDA 68] train loss=1.4656 acc=0.9939 | test acc=0.9061
# [LDA 69] train loss=1.4847 acc=0.9937 | test acc=0.9051
# [LDA 70] train loss=1.4730 acc=0.9938 | test acc=0.9058
# [LDA 71] train loss=1.4531 acc=0.9940 | test acc=0.9091
# [LDA 72] train loss=1.4330 acc=0.9948 | test acc=0.9085
# [LDA 73] train loss=1.4528 acc=0.9942 | test acc=0.9078
# [LDA 74] train loss=1.4527 acc=0.9945 | test acc=0.9029
# [LDA 75] train loss=1.4221 acc=0.9943 | test acc=0.9046
# [LDA 76] train loss=1.4402 acc=0.9947 | test acc=0.9072
# [LDA 77] train loss=1.4249 acc=0.9948 | test acc=0.9063
# [LDA 78] train loss=1.3975 acc=0.9958 | test acc=0.9051
# [LDA 79] train loss=1.3974 acc=0.9954 | test acc=0.9099
# [LDA 80] train loss=1.3947 acc=0.9958 | test acc=0.9074
# [LDA 81] train loss=1.3743 acc=0.9959 | test acc=0.9034
# [LDA 82] train loss=1.3808 acc=0.9955 | test acc=0.9116
# [LDA 83] train loss=1.3778 acc=0.9957 | test acc=0.9061
# [LDA 84] train loss=1.3809 acc=0.9961 | test acc=0.9099
# [LDA 85] train loss=1.3669 acc=0.9962 | test acc=0.9091
# [LDA 86] train loss=1.3872 acc=0.9955 | test acc=0.9035
# [LDA 87] train loss=1.3638 acc=0.9962 | test acc=0.9082
# [LDA 88] train loss=1.3546 acc=0.9967 | test acc=0.9066
# [LDA 89] train loss=1.3516 acc=0.9965 | test acc=0.9057
# [LDA 90] train loss=1.3485 acc=0.9966 | test acc=0.9057
# [LDA 91] train loss=1.3297 acc=0.9969 | test acc=0.9064
# [LDA 92] train loss=1.3229 acc=0.9969 | test acc=0.9036
# [LDA 93] train loss=1.3228 acc=0.9968 | test acc=0.9021
# [LDA 94] train loss=1.3115 acc=0.9975 | test acc=0.9067
# [LDA 95] train loss=1.3245 acc=0.9971 | test acc=0.9073
# [LDA 96] train loss=1.3172 acc=0.9972 | test acc=0.9133
# [LDA 97] train loss=1.3104 acc=0.9973 | test acc=0.9077
# [LDA 98] train loss=1.2986 acc=0.9974 | test acc=0.9094
# [LDA 99] train loss=1.3084 acc=0.9970 | test acc=0.9094
# [LDA 100] train loss=1.3018 acc=0.9976 | test acc=0.9099

# %%
import numpy as np
import matplotlib.pyplot as plt

lda_model.eval()
conf_list = []
pred_list = []
label_list = []
with torch.no_grad():
    for x, y in test_ld:
        x, y = x.to(device), y.to(device)
        logits = lda_model(x)
        probs = F.softmax(logits, dim=1)
        conf, pred = probs.max(1)
        conf_list.append(conf.cpu())
        pred_list.append(pred.cpu())
        label_list.append(y.cpu())

conf = torch.cat(conf_list).numpy()
pred = torch.cat(pred_list)
labels = torch.cat(label_list)
acc = (pred == labels).float().mean().item()
avg_conf = conf.mean().item()

bins = np.linspace(0.0, 1.0, 21)
weights = np.ones_like(conf) / conf.size

plt.figure(figsize=(4.5, 4.5))
plt.hist(conf, bins=bins, weights=weights, color='blue', edgecolor='black')
plt.axvline(avg_conf, color='gray', linestyle='--', linewidth=3)
plt.axvline(acc, color='gray', linestyle='--', linewidth=3)
plt.text(avg_conf, 0.95 * plt.gca().get_ylim()[1], 'Avg confidence',
         rotation=90, va='top', ha='center')
plt.text(acc, 0.95 * plt.gca().get_ylim()[1], 'Accuracy',
         rotation=90, va='top', ha='center')
plt.xlabel('Confidence')
plt.ylabel('% of Samples')
plt.xlim(0, 1)
plt.tight_layout()
plt.savefig('plots/cifar10_confidence_hist.png', dpi=600)

# %%
import numpy as np
import matplotlib.pyplot as plt

lda_model.eval()
conf_list = []
pred_list = []
label_list = []
with torch.no_grad():
    for x, y in test_ld:
        x, y = x.to(device), y.to(device)
        logits = lda_model(x)
        probs = F.softmax(logits, dim=1)
        conf, pred = probs.max(1)
        conf_list.append(conf.cpu())
        pred_list.append(pred.cpu())
        label_list.append(y.cpu())

conf = torch.cat(conf_list).numpy()
pred = torch.cat(pred_list).numpy()
labels = torch.cat(label_list).numpy()
correct = (pred == labels).astype(np.float32)

n_bins = 10
bins = np.linspace(0.0, 1.0, n_bins + 1)
bin_ids = np.digitize(conf, bins[1:-1], right=True)

bin_acc = np.zeros(n_bins, dtype=np.float32)
bin_conf = np.zeros(n_bins, dtype=np.float32)
bin_frac = np.zeros(n_bins, dtype=np.float32)

for b in range(n_bins):
    mask = bin_ids == b
    if mask.any():
        bin_acc[b] = correct[mask].mean()
        bin_conf[b] = conf[mask].mean()
        bin_frac[b] = mask.mean()

ece = np.sum(np.abs(bin_acc - bin_conf) * bin_frac)

bin_centers = (bins[:-1] + bins[1:]) / 2
bin_width = bins[1] - bins[0]

plt.figure(figsize=(4.5, 4.5))
plt.plot([0, 1], [0, 1], '--', color='gray', linewidth=3)
plt.bar(bin_centers, bin_acc, width=bin_width, color='blue', edgecolor='black', label='Outputs')
gap = bin_conf - bin_acc
plt.bar(bin_centers, gap, bottom=bin_acc, width=bin_width, color='salmon', edgecolor='red',
        alpha=0.4, hatch='//', label='Gap')
plt.xlabel('Confidence')
plt.ylabel('Accuracy')
plt.xlim(0, 1)
plt.ylim(0, 1)
plt.legend(loc='upper left')
plt.text(0.95, 0.05, f'ECE={ece*100:.2f}', ha='right', va='bottom',
         bbox=dict(boxstyle='round', facecolor='lightsteelblue', alpha=0.8))
plt.tight_layout()
plt.savefig('plots/cifar10_reliability_diagram.png', dpi=600)
