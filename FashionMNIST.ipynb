# %% [markdown]
# # Fashion-MNIST Classification with a Simplex LDA Head
# This notebook trains a small convolutional encoder with a linear discriminant analysis (LDA) head on Fashion-MNIST, then visualises the learned embedding space.

# %% [markdown]
# ### Setup

# %%
import torch, torch.nn as nn, torch.nn.functional as F
from torch.utils.data import DataLoader
from torchvision import datasets, transforms
from lda import SimplexLDAHead, DNLLLoss

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print('device =', device)
# Out:
# device = cuda

# %% [markdown]
# ### Data

# %%
tfm = transforms.ToTensor()
train_ds = datasets.FashionMNIST(root='./data', train=True, transform=tfm, download=True)
test_ds  = datasets.FashionMNIST(root='./data', train=False, transform=tfm, download=True)
train_ld = DataLoader(train_ds, batch_size=256, shuffle=True, num_workers=2, pin_memory=True)
test_ld  = DataLoader(test_ds,  batch_size=1024, shuffle=False, num_workers=2, pin_memory=True)
len(train_ds), len(test_ds)
# Out:
# (60000, 10000)

# %% [markdown]
# ### Model: encoder + LDA head (on-the-fly stats)

# %%
class Encoder(nn.Module):
    def __init__(self, dim):
        super().__init__()
        self.features = nn.Sequential(
            nn.Conv2d(1, 64, 3, padding=1), nn.BatchNorm2d(64), nn.ReLU(inplace=True),
            nn.Conv2d(64, 64, 3, padding=1), nn.BatchNorm2d(64), nn.ReLU(inplace=True),
            nn.MaxPool2d(2),
            nn.Conv2d(64, 128, 3, padding=1), nn.BatchNorm2d(128), nn.ReLU(inplace=True),
            nn.Conv2d(128, 128, 3, padding=1), nn.BatchNorm2d(128), nn.ReLU(inplace=True),
            nn.MaxPool2d(2),
            nn.Conv2d(128, 256, 3, padding=1), nn.BatchNorm2d(256), nn.ReLU(inplace=True),
            nn.Conv2d(256, 256, 3, padding=1), nn.BatchNorm2d(256), nn.ReLU(inplace=True),
            nn.AdaptiveAvgPool2d(1),
        )
        self.proj = nn.Linear(256, dim)

    def forward(self, x):
        x = self.features(x)
        x = torch.flatten(x, 1)
        return self.proj(x)

class DeepLDA(nn.Module):
    def __init__(self, C, D):
        super().__init__()
        self.encoder = Encoder(D)
        self.head = SimplexLDAHead(C, D)
    def forward(self, x):
        z = self.encoder(x)
        return self.head(z)

# %% [markdown]
# ### Train & Eval

# %%
@torch.no_grad()
def evaluate(model, loader):
    model.eval()
    ok = tot = 0
    for x, y in loader:
        x, y = x.to(device), y.to(device)
        logits = model(x)  # EMA stats
        ok += (logits.argmax(1) == y).sum().item()
        tot += y.size(0)
    return ok / tot

model = DeepLDA(C=10, D=9).to(device)
opt = torch.optim.Adam(model.encoder.parameters())
#loss_fn = nn.NLLLoss()
loss_fn = DNLLLoss()

for epoch in range(1, 101):
    model.train()
    loss_sum = acc_sum = n_sum = 0
    for x, y in train_ld:
        x, y = x.to(device), y.to(device)
        logits = model(x)        # uses batch stats + EMA update
        loss = loss_fn(logits, y)
        opt.zero_grad(set_to_none=True); loss.backward(); opt.step()
        with torch.no_grad():
            pred = logits.argmax(1)
            acc_sum += (pred == y).sum().item()
            n_sum += y.size(0)
            loss_sum += loss.item() * y.size(0)
    tr_acc = acc_sum / n_sum
    te_acc = evaluate(model, test_ld)
    print(f"[{epoch:02d}] train loss={loss_sum/n_sum:.4f} acc={tr_acc:.4f} | test acc={te_acc:.4f}")
# Out:
# [01] train loss=4.6423 acc=0.8502 | test acc=0.8499
# [02] train loss=3.8193 acc=0.9134 | test acc=0.8842
# [03] train loss=3.6082 acc=0.9272 | test acc=0.9138
# [04] train loss=3.4720 acc=0.9365 | test acc=0.9002
# [05] train loss=3.3892 acc=0.9434 | test acc=0.9059
# [06] train loss=3.2905 acc=0.9502 | test acc=0.9245
# [07] train loss=3.2075 acc=0.9560 | test acc=0.9153
# [08] train loss=3.1287 acc=0.9625 | test acc=0.9304
# [09] train loss=3.0529 acc=0.9687 | test acc=0.9148
# [10] train loss=2.9788 acc=0.9738 | test acc=0.9200
# [11] train loss=2.9224 acc=0.9785 | test acc=0.9208
# [12] train loss=2.8606 acc=0.9833 | test acc=0.9375
# [13] train loss=2.7983 acc=0.9869 | test acc=0.9003
# [14] train loss=2.7430 acc=0.9908 | test acc=0.8731
# [15] train loss=2.6988 acc=0.9930 | test acc=0.9291
# [16] train loss=2.6519 acc=0.9956 | test acc=0.9276
# [17] train loss=2.6192 acc=0.9966 | test acc=0.9334
# [18] train loss=2.5904 acc=0.9976 | test acc=0.9306
# [19] train loss=2.5660 acc=0.9985 | test acc=0.9256
# [20] train loss=2.5392 acc=0.9990 | test acc=0.9164
# [21] train loss=2.5356 acc=0.9990 | test acc=0.9298
# [22] train loss=2.5352 acc=0.9993 | test acc=0.9344
# [23] train loss=2.5220 acc=0.9994 | test acc=0.9261
# [24] train loss=2.5176 acc=0.9995 | test acc=0.9359
# [25] train loss=2.5071 acc=0.9996 | test acc=0.9346
# [26] train loss=2.4947 acc=0.9997 | test acc=0.9341
# [27] train loss=2.4813 acc=0.9998 | test acc=0.9196
# [28] train loss=2.4941 acc=0.9997 | test acc=0.9247
# [29] train loss=2.5086 acc=0.9997 | test acc=0.9231
# [30] train loss=2.4999 acc=0.9997 | test acc=0.9145
# [31] train loss=2.4851 acc=0.9998 | test acc=0.9299
# [32] train loss=2.4610 acc=0.9999 | test acc=0.9353
# [33] train loss=2.4512 acc=1.0000 | test acc=0.9317
# [34] train loss=2.4471 acc=1.0000 | test acc=0.9353
# [35] train loss=2.4460 acc=1.0000 | test acc=0.9305
# [36] train loss=2.5392 acc=0.9975 | test acc=0.9156
# [37] train loss=2.6268 acc=0.9952 | test acc=0.9185
# [38] train loss=2.4895 acc=0.9997 | test acc=0.9350
# [39] train loss=2.4491 acc=1.0000 | test acc=0.9377
# [40] train loss=2.4380 acc=1.0000 | test acc=0.9367
# [41] train loss=2.4329 acc=1.0000 | test acc=0.9380
# [42] train loss=2.4315 acc=1.0000 | test acc=0.9382
# [43] train loss=2.4311 acc=1.0000 | test acc=0.9362
# [44] train loss=2.4302 acc=1.0000 | test acc=0.9349
# [45] train loss=2.4309 acc=1.0000 | test acc=0.9381
# [46] train loss=2.4303 acc=1.0000 | test acc=0.9357
# [47] train loss=2.4369 acc=1.0000 | test acc=0.9288
# [48] train loss=2.6806 acc=0.9906 | test acc=0.9094
# [49] train loss=2.4889 acc=0.9996 | test acc=0.9370
# [50] train loss=2.4416 acc=1.0000 | test acc=0.9354
# [51] train loss=2.4307 acc=1.0000 | test acc=0.9368
# [52] train loss=2.4263 acc=1.0000 | test acc=0.9367
# [53] train loss=2.4233 acc=1.0000 | test acc=0.9359
# [54] train loss=2.4219 acc=1.0000 | test acc=0.9368
# [55] train loss=2.4205 acc=1.0000 | test acc=0.9350
# [56] train loss=2.4209 acc=1.0000 | test acc=0.9364
# [57] train loss=2.4210 acc=1.0000 | test acc=0.9376
# [58] train loss=2.4222 acc=1.0000 | test acc=0.9359
# [59] train loss=2.4292 acc=1.0000 | test acc=0.9276
# [60] train loss=2.6260 acc=0.9930 | test acc=0.9271
# [61] train loss=2.4800 acc=0.9995 | test acc=0.9333
# [62] train loss=2.4337 acc=1.0000 | test acc=0.9363
# [63] train loss=2.4217 acc=1.0000 | test acc=0.9379
# [64] train loss=2.4198 acc=1.0000 | test acc=0.9362
# [65] train loss=2.4178 acc=1.0000 | test acc=0.9370
# [66] train loss=2.4159 acc=1.0000 | test acc=0.9378
# [67] train loss=2.4164 acc=1.0000 | test acc=0.9380
# [68] train loss=2.4162 acc=1.0000 | test acc=0.9360
# [69] train loss=2.4158 acc=1.0000 | test acc=0.9356
# [70] train loss=2.4152 acc=1.0000 | test acc=0.9340
# [71] train loss=2.4162 acc=1.0000 | test acc=0.9365
# [72] train loss=2.4162 acc=1.0000 | test acc=0.9346
# [73] train loss=2.5182 acc=0.9962 | test acc=0.9236
# [74] train loss=2.5497 acc=0.9968 | test acc=0.9232
# [75] train loss=2.4437 acc=0.9999 | test acc=0.9319
# [76] train loss=2.4213 acc=1.0000 | test acc=0.9360
# [77] train loss=2.4168 acc=1.0000 | test acc=0.9368
# [78] train loss=2.4146 acc=1.0000 | test acc=0.9370
# [79] train loss=2.4138 acc=1.0000 | test acc=0.9373
# [80] train loss=2.4124 acc=1.0000 | test acc=0.9370
# [81] train loss=2.4127 acc=1.0000 | test acc=0.9363
# [82] train loss=2.4119 acc=1.0000 | test acc=0.9346
# [83] train loss=2.4116 acc=1.0000 | test acc=0.9362
# [84] train loss=2.4115 acc=1.0000 | test acc=0.9364
# [85] train loss=2.4113 acc=1.0000 | test acc=0.9361
# [86] train loss=2.4119 acc=1.0000 | test acc=0.9380
# [87] train loss=2.4144 acc=1.0000 | test acc=0.9253
# [88] train loss=2.6101 acc=0.9933 | test acc=0.9314
# [89] train loss=2.4484 acc=0.9998 | test acc=0.9365
# [90] train loss=2.4207 acc=1.0000 | test acc=0.9366
# [91] train loss=2.4145 acc=1.0000 | test acc=0.9367
# [92] train loss=2.4125 acc=1.0000 | test acc=0.9373
# [93] train loss=2.4118 acc=1.0000 | test acc=0.9360
# [94] train loss=2.4109 acc=1.0000 | test acc=0.9370
# [95] train loss=2.4102 acc=1.0000 | test acc=0.9369
# [96] train loss=2.4096 acc=1.0000 | test acc=0.9371
# [97] train loss=2.4096 acc=1.0000 | test acc=0.9378
# [98] train loss=2.4094 acc=1.0000 | test acc=0.9359
# [99] train loss=2.4095 acc=1.0000 | test acc=0.9379
# [100] train loss=2.4096 acc=1.0000 | test acc=0.9337

# %%
import matplotlib.pyplot as plt

model.eval()
embeds, labels = [], []
with torch.no_grad():
    for i, (x, y) in enumerate(train_ld):   # use train_ld if you prefer
        x = x.to(device)
        z = model.encoder(x).cpu()
        embeds.append(z)
        labels.append(y)
        if i >= 9:   # 10 batches ≈10k points; raise/lower to taste
            break

z = torch.cat(embeds)
y = torch.cat(labels)

# 2D projection (PCA)
z0 = z - z.mean(0, keepdim=True)
U, S, V = torch.pca_lowrank(z0, q=2)
z2 = z0 @ V[:, :2]

plt.rcParams.update({
    "font.size": 14, "axes.labelsize": 16, "legend.fontsize": 13,
    "xtick.labelsize": 13, "ytick.labelsize": 13
})

plt.figure(figsize=(8, 6))
for c in range(10):
    idx = y == c
    plt.scatter(z2[idx, 0], z2[idx, 1], s=8, alpha=0.6, label=train_ds.classes[c])
plt.legend(bbox_to_anchor=(1.02, 1), loc="upper left")
plt.xlabel("PC1"); plt.ylabel("PC2")
plt.tight_layout()
plt.savefig('plots/fmnist_lda_embeddings.png', dpi=600)

# %%
import numpy as np
import matplotlib.pyplot as plt

model.eval()
conf_list = []
pred_list = []
label_list = []

with torch.no_grad():
    for x, y in test_ld:
        x, y = x.to(device), y.to(device)
        logits = model(x)
        probs = F.softmax(logits, dim=1)
        conf, pred = probs.max(1)
        conf_list.append(conf.cpu())
        pred_list.append(pred.cpu())
        label_list.append(y.cpu())

conf = torch.cat(conf_list).numpy()
pred = torch.cat(pred_list).numpy()
labels = torch.cat(label_list).numpy()
acc = (pred == labels).mean()
avg_conf = conf.mean().item()

bins = np.linspace(0.0, 1.0, 21)
weights = np.ones_like(conf) / conf.size

plt.figure(figsize=(4.5, 4.5))
plt.hist(conf, bins=bins, weights=weights, color='blue', edgecolor='black')
plt.axvline(avg_conf, color='gray', linestyle='--', linewidth=3)
plt.axvline(acc, color='gray', linestyle='--', linewidth=3)
plt.text(avg_conf, 0.95 * plt.gca().get_ylim()[1], 'Avg confidence',
         rotation=90, va='top', ha='center')
plt.text(acc, 0.95 * plt.gca().get_ylim()[1], 'Accuracy',
         rotation=90, va='top', ha='center')
plt.xlabel('Confidence')
plt.ylabel('% of Samples')
plt.xlim(0, 1)
plt.tight_layout()
plt.savefig('plots/fashionmnist_confidence_hist.png', dpi=600)

# %%
import numpy as np
import matplotlib.pyplot as plt

model.eval()
conf_list = []
pred_list = []
label_list = []
with torch.no_grad():
    for x, y in test_ld:
        x, y = x.to(device), y.to(device)
        logits = model(x)
        probs = F.softmax(logits, dim=1)
        conf, pred = probs.max(1)
        conf_list.append(conf.cpu())
        pred_list.append(pred.cpu())
        label_list.append(y.cpu())

conf = torch.cat(conf_list).numpy()
pred = torch.cat(pred_list).numpy()
labels = torch.cat(label_list).numpy()
correct = (pred == labels).astype(np.float32)

n_bins = 10
bins = np.linspace(0.0, 1.0, n_bins + 1)
bin_ids = np.digitize(conf, bins[1:-1], right=True)

bin_acc = np.zeros(n_bins, dtype=np.float32)
bin_conf = np.zeros(n_bins, dtype=np.float32)
bin_frac = np.zeros(n_bins, dtype=np.float32)

for b in range(n_bins):
    mask = bin_ids == b
    if mask.any():
        bin_acc[b] = correct[mask].mean()
        bin_conf[b] = conf[mask].mean()
        bin_frac[b] = mask.mean()

ece = np.sum(np.abs(bin_acc - bin_conf) * bin_frac)

bin_centers = (bins[:-1] + bins[1:]) / 2
bin_width = bins[1] - bins[0]

plt.figure(figsize=(4.5, 4.5))
plt.plot([0, 1], [0, 1], '--', color='gray', linewidth=3)
plt.bar(bin_centers, bin_acc, width=bin_width, color='blue', edgecolor='black', label='Outputs')
gap = bin_conf - bin_acc
plt.bar(bin_centers, gap, bottom=bin_acc, width=bin_width, color='salmon', edgecolor='red',
        alpha=0.4, hatch='//', label='Gap')
plt.xlabel('Confidence')
plt.ylabel('Accuracy')
plt.xlim(0, 1)
plt.ylim(0, 1)
plt.legend(loc='upper left')
plt.text(0.95, 0.05, f'ECE={ece*100:.2f}', ha='right', va='bottom',
         bbox=dict(boxstyle='round', facecolor='lightsteelblue', alpha=0.8))
plt.tight_layout()
plt.savefig('plots/fashionmnist_reliability_diagram.png', dpi=600)
